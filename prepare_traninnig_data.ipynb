# %%
import glob
import pandas as pd

# %% [markdown]
# # combine features participants to one file

# %%
data_types = {
    'HEADSET': ['EEG','head motion',],
              'EYETRACKER': ['PUPIL', 'GAZE'], 
              'WRISTBAND': ['EDA', 'ACC']
             }

info_cols =  ['tw', 'n', 'task', 'name', 'durations', 'start', 'end', 'stage', 'Topic', 'Input', 'Output', 'start_sec', 'end_sec', 'PID']

def format_name(c, prefix):
    if not c.startswith(prefix):
        c = c.replace(':_', '_')
        c = c.replace(':', '_')
        return prefix+':'+c
    return c

for tw in ['4-2', '2-1', '1-0']:
    for folder, types in data_types.items():
        for typ in types:
            files = glob.glob(f'../data/MUWIS-dataset/{folder}/features/{typ}/**features({tw}).csv')
            print(f'Found {len(files)} files in total for data type: {typ}') 
            print(f'Reading {files[0]} to combine')
            
            data = None
            for file in files:
                df = pd.read_csv(file, low_memory=False)
                print(df.head(2))
        
                if data is None: data = df
                else:
                    data = pd.concat([data, df])
            
            if data is None:
                raise 'Error No Data Read'
            else:
                data.reset_index(inplace=True, drop=True)
                
                if typ == 'EEG': #format feature names
                    feature_cols = [c for c in data.columns if c not in info_cols + ['PID']]
                    rename_cols = {c: format_name(c, 'EEG') for c in feature_cols}
                    data.rename(columns=rename_cols, inplace=True)
                elif typ == 'PUPIL':
                    feature_cols = [c for c in data.columns if c not in info_cols + ['PID']]
                    rename_cols = {c: format_name(c, 'EYE') for c in feature_cols}
                    data.rename(columns=rename_cols, inplace=True)
                out_f = f'../data/MUWIS-dataset/{folder}/features/{typ}_features_combined{tw}.csv'
                data.to_csv(out_f, index=False)
                print('DONE', out_f)
# Out:
# Found 20 files in total for data type: EEG
# Reading ../data/MUWIS-dataset/HEADSET/features/EEG/PA19_EEG_features(4-2).csv to combine
#    n  hjorthActivity:_AF3  hjorthActivity:_F7  hjorthActivity:_F3  \
# 0  0            -7.341109          -17.207206            0.947003
# 1  1            -5.987132          -21.940290            2.917019
#
#    hjorthActivity:_FC5  hjorthActivity:_T7  hjorthActivity:_P7  \
# 0            -66.47854          -11.591927           69.411316
# 1            -68.65510          -10.981664           96.786028
#
#    hjorthActivity:_O1  hjorthActivity:_O2  hjorthActivity:_P8  ...  task  \
# 0           -6.279556           -4.327094          -42.704262  ...     1
# 1           -4.344129           -5.145281          -22.924096  ...     1
#
#                name  durations                             start  \
# 0  information need     49.094  2023-09-01 09:52:52.962000+10:00
# 1  information need     49.094  2023-09-01 09:52:52.962000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-01 09:53:42.056000+10:00     IN  433.0  573.530048  622.624048
# 1  2023-09-01 09:53:42.056000+10:00     IN  433.0  573.530048  622.624048
#
#     PID
# 0  PA19
# 1  PA19
#
# [2 rows x 472 columns]
#    n  hjorthActivity:_AF3  hjorthActivity:_F7  hjorthActivity:_F3  \
# 0  0            -1.504748           50.943639          -23.794621
# 1  1            -0.089571           50.415000          -21.670998
#
#    hjorthActivity:_FC5  hjorthActivity:_T7  hjorthActivity:_P7  \
# 0             9.464588            2.060859           10.427378
# 1             5.019828           35.571649           13.861847
#
#    hjorthActivity:_O1  hjorthActivity:_O2  hjorthActivity:_P8  ...  task  \
# 0            5.458668            1.655906          -84.010935  ...     1
# 1           -1.493942            0.907529          -89.050347  ...     1
#
#                name  durations                             start  \
# 0  information need     39.359  2023-08-28 10:24:19.350000+10:00
# 1  information need     39.359  2023-08-28 10:24:19.350000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-08-28 10:24:58.709000+10:00     IN  743.0  644.042948  683.401948
# 1  2023-08-28 10:24:58.709000+10:00     IN  743.0  644.042948  683.401948
#
#     PID
# 0  PA13
# 1  PA13
#
# [2 rows x 472 columns]
#    n  hjorthActivity:_AF3  hjorthActivity:_F7  hjorthActivity:_F3  \
# 0  0            -2.747895            5.538765          -11.181251
# 1  1            -2.105400            8.844489           -8.890131
#
#    hjorthActivity:_FC5  hjorthActivity:_T7  hjorthActivity:_P7  \
# 
#
#    MOTION:MAG_meanY  MOTION:MAG_meanZ  MOTION:ACC_magmean  \
# 0          1.350224         -1.996168           -1.299259
# 1          1.572606         -2.172088           -1.150696
#
#    MOTION:ACC_magenergy   tw  n task              name  durations  \
# 0              0.019215  4-2  2    1              gap1      4.046
# 1              0.020893  4-2  2    1  information need     16.430
#
#                               start                               end stage  \
# 0  2023-08-24 09:47:43.345000+10:00  2023-08-24 09:47:47.391000+10:00    +1
# 1  2023-08-24 09:47:55.479000+10:00  2023-08-24 09:48:11.909000+10:00    IN
#
#    Topic   start_sec     end_sec  PID
# 0  433.0  256.294231  260.340231  PA5
# 1  433.0  268.428231  284.858231  PA5
#    MOTION:ACC_meanX  MOTION:ACC_meanY  MOTION:ACC_meanZ  MOTION:MAG_meanX  \
# 0         -0.350060          0.670373         -0.463195         -0.895612
# 1          0.546281         -0.098046         -0.301088          0.763308
#
#    MOTION:MAG_meanY  MOTION:MAG_meanZ  MOTION:ACC_magmean  \
# 0         -0.246981          0.501821            0.705260
# 1          0.101219          0.260945            0.001251
#
#    MOTION:ACC_magenergy   tw  n task              name  durations  \
# 0              0.087204  4-2  2    1              gap1      4.116
# 1              0.059183  4-2  2    1  information need     17.742
#
#                               start                               end stage  \
# 0  2023-09-19 11:57:40.753000+10:00  2023-09-19 11:57:44.869000+10:00    +1
# 1  2023-09-19 11:58:10.033000+10:00  2023-09-19 11:58:27.775000+10:00    IN
#
#    Topic  start_sec    end_sec   PID
# 0  725.0  605.07428  609.19028  PA29
# 1  725.0  634.35428  652.09628  PA29
# DONE ../data/MUWIS-dataset/HEADSET/features/head motion_features_combined4-2.csv
# Found 18 files in total for data type: PUPIL
# Reading ../data/MUWIS-dataset/EYETRACKER/features/PUPIL/PA22_pupil_features(4-2).csv to combine
#    PUPIL_median  PUPIL_max  PUPIL_min  PUPIL_mean  PUPIL_std  PUPIL_range  \
# 0     -0.042232   0.038291  -0.007084   -0.023789   0.009352     0.045375
# 1     -0.030260  -0.108771   0.022306   -0.030626  -0.040757    -0.131077
#
#    nblink  PUPIL_mean_RPD  PUPIL_max_RPD  PUPIL_min_RPD  ...  task  \
# 0       1       -0.009518       0.015320      -0.002834  ...     1
# 1       1       -0.012253      -0.043519       0.008925  ...     1
#
#                name  durations                             start  \
# 0              gap1      4.015  2023-09-04 15:25:35.186000+10:00
# 1  information need     11.481  2023-09-04 15:25:49.662000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-04 15:25:39.201000+10:00     +1  320.0  434.732456  438.747456
# 1  2023-09-04 15:26:01.143000+10:00     IN  320.0  449.208456  460.689456
#
#     PID
# 0  PA22
# 1  PA22
#
# [2 rows x 38 columns]
#    PUPIL_median  PUPIL_max  PUPIL_min  PUPIL_mean  PUPIL_std  PUPIL_range  \
# 0      0.290148   0.153004   0.270152    0.258018  -0.020743    -0.117148
# 1      0.260504   0.077373   0.304558    0.251302  -0.065045    -0.227185
#
#      nblink  PUPIL_mean_RPD  PUPIL_max_RPD  PUPIL_min_RPD  ...  task  \
# 0  0.333333        0.091087       0.054015       0.095371  ...     1
# 1 -0.666667        0.088716       0.027315       0.107517  ...     1
#
#                name  durations                             start  \
# 0              gap1      4.010  2023-09-25 09:46:20.271000+10:00
# 1  information need      7.807  2023-09-25 09:46:35.617000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-25 09:46:24.281000+10:00     +1  353.0  348.305221  352.315221
# 1  2023-09-25 09:46:43.424000+10:00     IN  353.0  363.651221  371.458221
#
#     PID
# 0  PA32
# 1  PA32
#
# [2 rows x 38 columns]
#    PUPIL_median  PUPIL_max  PUPIL_min  PUPIL_mean  PUPIL_std  PUPIL_range  \
# 0      0.082480   0.159731   0.141046    0.120532   0.020993     0.018685
# 1      0.131434  -0.047805   0.176426    0.115437  -0.045997    -0.224230
#
#    nblink  PUPIL_mean_RPD  PUPIL_max_RPD  PUPIL_min_RPD  ...  task  \
# 0      -1        0.046719       0.061912       0.054670  ...     1
# 1       0        0.044744      -0.018529       0.068383  ...     1
#
#                name  durations                             start  \
# 0              gap1      4.118  2023-08-25 13:22:49.611000+10:00
# 1  information need      8.746  2023-08-25 13:23:05.896000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-08-25 13:22:53.729000+10:00     +1  725.0  514.803154  518.921154
# 1  2023-08-25 13:23:14.642000+10:00     IN  725.0  531.088154  539.834154
#
#     PID
# 0  PA12
# 1  PA12
#
# [2 rows x 38 columns]
#    PUPIL_median  PUPIL_max  PUPIL_min  PUPIL_mean  PUPIL_std  PUPIL_range  \
# 0     -0.064096  -0.182093  -0.068947   -0.083978  -0.028468    -0.113146
# 1     -0.135091  -0.325331  -0.031076   -0.136516  -0.079632    -0.294255
#
#      nblink  PUPIL_mean_RPD  PUPIL_max_RPD  PUPIL_min_RPD  ...  task  \
# 0  0.666667       -0.035079      -0.076064      -0.028801  ...     1
# 1  0.666667       -0.057026      -0.135898      -0.012981  ...     1
#
#                name  durations                             start  \
# 0              gap1      4.014  2023-09-12 13:00:55.774000+10:00
# 1  information need     14.746  2023-09-12 13:01:15.378000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-12 13:00:59.788000+10:00     +1  353.0  444.202587  448.216587
# 1  2023-09-12 13:01:30.124000+10:00     IN  353.0  463.806587  478.552587
#
#     PID
# 0  PA26
# 1  PA26
#
# [2 rows x 38 columns]
#    PUPIL_median  PUPIL_max  PUPIL_min  PUPIL_mean  PUPIL_std  PUPIL_range  \
# 0      0.227002   0.012164   0.220296    0.213309  -0.091583    -0.208131
# 1      0.332656   0.289049   0.396612    0.344935  -0.041496    -0.107562
#
#    nblink  PUPIL_mean_RPD  PUPIL_max_RPD  PUPIL_min_RPD  ...  task  \
# 0     0.5        0.068904       0.003929       0.071161  ...     1
# 1     0.5        0.111423       0.093370       0.128116  ...     1
#
#                name  durations                             start  \
# 0              gap1      4.118  2023-09-20 10:48:37.283000+10:00
# 1  information need     11.713  2023-09-20 10:48:52.252000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-20 10:48:41.401000+10:00     +1  314.0  368.027277  372.145277
# 1  2023-09-20 10:49:03.965000+10:00     IN  314.0  382.996277  394.709277
#
#     PID
# 0  PA31
# 1  PA31
#
# [2 rows x 38 columns]
#    PUPIL_median  PUPIL_max  PUPIL_min  PUPIL_mean  PUPIL_std  PUPIL_range  \
# 0     -0.171571  -0.187172  -0.175986   -0.165072  -0.012706    -0.011186
# 1      0.003172  -0.169416   0.047420   -0.006118  -0.059581    -0.216836
#
#      nblink  PUPIL_mean_RPD  PUPIL_max_RPD  PUPIL_min_RPD  ...  task  \
# 0 -0.166667       -0.058062      -0.065836      -0.061901  ...     1
# 1 -0.166667       -0.002152      -0.059590       0.016679  ...     1
#
#                name  durations                             start  \
# 0              gap1      4.014  2023-09-03 11:41:38.654000+10:00
# 1  information need     32.605  2023-09-03 11:41:56.515000+10:00
#
# ...
#
#    E4:EDA_kurtosis  E4:EDA_d1mean  E4:EDA_d2mean  E4:SCL_amp  E4:SCL_sd  \
# 0              NaN      -0.001016      -0.000508    4.311510   0.050124
# 1              NaN      -0.001016      -0.000508    4.177328   0.070993
#
#    E4:SCL_mean  ...  task  name  durations                             start  \
# 0    -9.711380  ...     1  gap1      4.014  2023-09-03 11:41:38.654000+10:00
# 1    -9.443016  ...     1  gap1      4.014  2023-09-03 11:41:38.654000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-03 11:41:42.668000+10:00     +1  711.0  341.514628  345.528628
# 1  2023-09-03 11:41:42.668000+10:00     +1  711.0  341.514628  345.528628
#
#     PID
# 0  PA21
# 1  PA21
#
# [2 rows x 43 columns]
#    E4:EDA_mean  E4:EDA_median  E4:EDA_variance  E4:EDA_skewness  \
# 0     2.412723       2.752257         0.047995        -0.538689
# 1     2.463815       2.752257         0.047995        -0.538689
#
#    E4:EDA_kurtosis  E4:EDA_d1mean  E4:EDA_d2mean  E4:SCL_amp  E4:SCL_sd  \
# 0        -1.339578      -0.021158      -0.010579   -0.279277   0.002344
# 1        -1.339578       0.031437       0.015718   -0.266371   0.002195
#
#    E4:SCL_mean  ...  task  name  durations                             start  \
# 0     2.024451  ...     1  gap1      4.011  2023-09-14 10:54:26.865000+10:00
# 1     2.050263  ...     1  gap1      4.011  2023-09-14 10:54:26.865000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-14 10:54:30.876000+10:00     +1  708.0  437.143075  441.154075
# 1  2023-09-14 10:54:30.876000+10:00     +1  708.0  437.143075  441.154075
#
#     PID
# 0  PA27
# 1  PA27
#
# [2 rows x 43 columns]
#    E4:EDA_mean  E4:EDA_median  E4:EDA_variance  E4:EDA_skewness  \
# 0    -1.089379      -1.765348         0.123915         0.611359
# 1    -1.299000      -1.765348         0.123915         0.611359
#
#    E4:EDA_kurtosis  E4:EDA_d1mean  E4:EDA_d2mean  E4:SCL_amp  E4:SCL_sd  \
# 0        -0.923638       0.001102       0.000551    0.179459   0.012103
# 1        -0.923638       0.205217       0.102608    0.212511  -0.002291
#
#    E4:SCL_mean  ...  task  name  durations                             start  \
# 0    -2.803434  ...     1  gap1      4.118  2023-09-20 10:48:37.283000+10:00
# 1    -2.869539  ...     1  gap1      4.118  2023-09-20 10:48:37.283000+10:00
#
#                                 end  stage  Topic   start_sec     end_sec  \
# 0  2023-09-20 10:48:41.401000+10:00     +1  314.0  368.027277  372.145277
# 1  2023-09-20 10:48:41.401000+10:00     +1  314.0  368.027277  372.145277
#
#     PID
# 0  PA31
# 1  PA31
#
# [2 rows x 43 columns]
# DONE ../data/MUWIS-dataset/WRISTBAND/features/EDA_features_combined1-0.csv
# Found 20 files in total for data type: ACC
# Reading ../data/MUWIS-dataset/WRISTBAND/features/ACC/PA31_ACC_features(1-0).csv to combine
#    E4:ACC_mean  E4:ACC_sd  E4:ACC_range  E4:ACC_max  E4:ACC_min   tw  n task  \
# 
print(f'Found {len(files)} files in total') 
print(f'Reading {files[0]} to combine')
data = None
for file in files:
    df = pd.read_csv(file, low_memory=False)
    if data is None: data = df
    else:
        data = pd.concat([data, df])
data.reset_index(inplace=True, drop=True)
if data is None:
    raise 'Error No Data Read'
else:
    data.to_csv('../data/MUWIS-dataset/EYETRACKER/features/GAZE_features_combined.csv')

# %% [markdown]
# # group the features and prepare for trainning

# %%
def convert(df, columns):
    X = df[df[target_name].isin(target_set)][columns]
    print(X.shape)
    X[target_name] = le4.transform(X[target_name])
    print(X[target_name].value_counts())
    return X


def fill_nan_with_mean(df, feature_cols):
    for column in feature_cols:
        df[column] = df.groupby('PID')[column].transform(lambda x: x.fillna(x.mean()))
    return df
    
def read_data(file):
    gaps = ['+1', '+2', '+3', '+4', '+5']
    info_cols =  ['task', 'stage', 'Topic','name',]
    remove_cols = [ 'start', 'end', 'start_sec', 'end_sec', 'durations', ]
    time_window_cols = ['tw', 'n']
    id_col = ['PID']

    df = pd.read_csv(file)
    if time_window_cols[0] in df.columns.values:
        df.drop(columns=time_window_cols, inplace=True)
    df.drop(columns=remove_cols, inplace=True)
    
    empty_cols = [col for col in df.columns if col.__contains__('Unnamed') ]
    print('empty columns', empty_cols)
    if len(empty_cols) != 0:
        df.drop(columns=empty_cols, inplace=True)
        
    df = df[~df.stage.isin(gaps+['Break'])]
    for c in ['task', 'Topic']:
        df[c] = df[c].apply(lambda x: str(x))

    feature_cols = [c for c in df.columns if c not in id_col+info_cols]
    df = fill_nan_with_mean(df, feature_cols)
    
    df = df.groupby(id_col+info_cols).mean().reset_index()
    check = df[['PID', 'task']].value_counts().mean()
    if check == 6:
        print('valid data')
    else:
        print(check, 'Might have grouping error!', file)
    return df

# %%
import re
from sklearn.preprocessing import LabelEncoder

EXPORT = 1 

info_cols =  ['task', 'stage', 'Topic', 'PID']
id_col = ['PID']
unwanted = ['tw', 'n', 'name', 'start', 'end', 'start_sec','end_sec','durations',]

target_name = 'stage'
target_set = ['IN', 'QF', 'LISTEN','READ', 'TYPE', 'SPEAK']
le4 = LabelEncoder().fit(target_set)

data_files = glob.glob('../data/MUWIS-dataset/features/**')
print(data_files)

while data_files:
    file = data_files.pop(0)
        
    print('='*15)
    print(file)
    print('='*15)
    
    try:
        tw = re.match('.*(\d-\d).*', file).group(1)
    except:
        tw=''
        
    df = read_data(file)
    
    if file.__contains__('EEG'):
        df.rename(columns={c: c[:-2] for c in df.columns.values if re.match('EEG:curve_length_([A-Z]{1,2}\d)_0', c)}, inplace=True)
        features_cols =df.columns.values
        features_cols = [c for c in features_cols if c not in info_cols + id_col + unwanted]
        print('Extracted', len(features_cols), 'features in total', features_cols[0])
        
        gf = [f for f in features_cols if f.__contains__('inter') or f.__contains__('intra')]
        print(len(gf), 'group EEG features')
        sf = [f for f in features_cols if re.match('EEG:(?:(.*)_(?:([A-Z]{1,2}\d)))$', f) and \
              re.match('EEG:(?:(.*)_(?:([A-Z]{1,2}\d)))$', f).group(1) in [\
            'mean', 'std',  'skewness', 'kurtosis', 'npeaks', 'wavelet_entropy', 'curve_length', 'zero_crossings']]
        print(len(sf), 'statistic EEG features')
        ff = [f for f in features_cols if re.match('EEG:(?:(.*)_(?:[A-Z]{1,2}\d_[a-z]{4,}))$', f) and 
              re.match('EEG:(?:(.*)_(?:[A-Z]{1,2}\d_[a-z]{4,}))$', f).group(1) in [\
            'bandPower_PSD_norm',]]
        print(len(ff), 'frequency EEG features')
        selected = gf + sf + ff
        print(len(selected), 'EEG features')
        
        features_cols = selected
        
        outf = f'trainning data/EEG(6 {tw}).csv'
        
        
    elif file.__contains__('EDA'):
        features_cols =df.columns.values
        features_cols = [c for c in features_cols if c not in info_cols + id_col + unwanted]
        print('Extracted', len(features_cols), 'features in total', features_cols[0])
        print(features_cols)
        outf = f'trainning data/EDA(6 {tw}).csv'
        
    elif file.__contains__('PUPIL'):
        features_cols =df.columns.values
        features_cols = [c for c in features_cols if c not in info_cols + id_col + unwanted]
        print('Extracted', len(features_cols), 'features in total', features_cols[0])
        print(features_cols)
        outf = f'trainning data/PUPIL(6 {tw}).csv'

    elif file.__contains__('ACC') or file.__contains__('head motion'):
        if file.__contains__('ACC'):
            f2 = file.replace('ACC', 'head motion')
        elif file.__contains__('head motion'):
            f2 = file.replace('head motion', 'ACC')
    
        if f2 in data_files: 
            data_files.remove(f2)
            print('to combine with', f2)
            df2 = read_data(f2)
            print('before merge:', df.shape, df2.shape)
        
        else: 
            print('ERROR!!', f2, 'not exist' )
            continue
        
        columns = list(df.columns) +  list(df2.columns)
        rename = {}
        for c in columns:
            if c.__contains__('E4'):
                rename.update({c: c.replace('E4:', 'MOTION:WR_')})
            elif c.__contains__('MOTION'):
                rename.update({c: c.replace('MOTION:', 'MOTION:HD_')})
        df.rename(columns=rename, inplace=True)
        df2.rename(columns=rename, inplace=True)
        
        df = pd.merge(left=df, right=df2, on=['PID', 'task', 'stage', 'Topic', 'name'], how='inner')
        print('after merge:', df.shape)
    
        features_cols = df.columns.values
        features_cols = [c for c in features_cols if c not in info_cols + id_col + unwanted]
        print('Extracted', len(features_cols), 'features in total', features_cols[0])
        print(features_cols)
        outf = f'trainning data/MOTION(6 {tw}).csv'

    elif file.__contains__('GAZE'):
        features_cols =df.columns.values
        features_cols = [c for c in features_cols if c not in info_cols + id_col + unwanted]
        print('Extracted', len(features_cols), 'features in total', features_cols[0])
        print(features_cols)
        outf = f'trainning data/GAZE(6 {tw}).csv'
    
    X = convert(df, features_cols + info_cols)
    if EXPORT == 1:
        X.to_csv(outf, index=False) 
        print('DONE!!', outf)
        print('!'*15)
# Out:
# ['../data/MUWIS-dataset/features/GAZE_features_combined.csv', '../data/MUWIS-dataset/features/EEG_features_combined2-1.csv', '../data/MUWIS-dataset/features/EEG_features_combined1-0.csv', '../data/MUWIS-dataset/features/EEG_features_combined4-2.csv', '../data/MUWIS-dataset/features/GAZE_features_combined4-2.csv', '../data/MUWIS-dataset/features/GAZE_features_combined1-0.csv', '../data/MUWIS-dataset/features/GAZE_features_combined2-1.csv', '../data/MUWIS-dataset/features/PUPIL_features_combined1-0.csv', '../data/MUWIS-dataset/features/EDA_features_combined1-0.csv', '../data/MUWIS-dataset/features/PUPIL_features_combined4-2.csv', '../data/MUWIS-dataset/features/EDA_features_combined4-2.csv', '../data/MUWIS-dataset/features/EDA_features_combined2-1.csv', '../data/MUWIS-dataset/features/PUPIL_features_combined2-1.csv', '../data/MUWIS-dataset/features/ACC_features_combined2-1.csv', '../data/MUWIS-dataset/features/head motion_features_combined4-2.csv', '../data/MUWIS-dataset/features/head motion_features_combined1-0.csv', '../data/MUWIS-dataset/features/ACC_features_combined4-2.csv', '../data/MUWIS-dataset/features/head motion_features_combined2-1.csv', '../data/MUWIS-dataset/features/ACC_features_combined1-0.csv']
# ===============
# ../data/MUWIS-dataset/features/GAZE_features_combined.csv
# ===============
# empty columns []
# 5.5895196506550215 Might have grouping error! ../data/MUWIS-dataset/features/GAZE_features_combined.csv
# Extracted 6 features in total EYE:GAZE_fixation_count
# ['EYE:GAZE_fixation_count', 'EYE:GAZE_fixation_total_duration', 'EYE:GAZE_fixation_mean_duration', 'EYE:GAZE_saccade_count', 'EYE:GAZE_saccade_total_duration', 'EYE:GAZE_saccade_mean_duration']
# (840, 10)
# stage
# 0    211
# 2    210
# 5    107
# 3    106
# 1    105
# 4    101
# Name: count, dtype: int64
# DONE!! trainning data/GAZE(6 ).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/EEG_features_combined2-1.csv
# ===============
# /tmp/ipykernel_39361/1518536451.py:21: DtypeWarning: Columns (462,468) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# empty columns []
# 5.686274509803922 Might have grouping error! ../data/MUWIS-dataset/features/EEG_features_combined2-1.csv
# Extracted 460 features in total EEG:hjorthActivity_AF3
# 12 group EEG features
# 112 statistic EEG features
# 56 frequency EEG features
# 180 EEG features
# (940, 184)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    116
# Name: count, dtype: int64
# DONE!! trainning data/EEG(6 2-1).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/EEG_features_combined1-0.csv
# ===============
# /tmp/ipykernel_39361/1518536451.py:21: DtypeWarning: Columns (462,468) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# empty columns []
# 5.686274509803922 Might have grouping error! ../data/MUWIS-dataset/features/EEG_features_combined1-0.csv
# Extracted 460 features in total EEG:hjorthActivity_AF3
# 12 group EEG features
# 112 statistic EEG features
# 56 frequency EEG features
# 180 EEG features
# (940, 184)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    116
# Name: count, dtype: int64
# DONE!! trainning data/EEG(6 1-0).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/EEG_features_combined4-2.csv
# ===============
# empty columns []
# 5.666666666666667 Might have grouping error! ../data/MUWIS-dataset/features/EEG_features_combined4-2.csv
# Extracted 460 features in total EEG:hjorthActivity_AF3
# 12 group EEG features
# 112 statistic EEG features
# 56 frequency EEG features
# 180 EEG features
# (935, 184)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    111
# Name: count, dtype: int64
# DONE!! trainning data/EEG(6 4-2).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/GAZE_features_combined4-2.csv
# ===============
# empty columns []
# 5.397379912663755 Might have grouping error! ../data/MUWIS-dataset/features/GAZE_features_combined4-2.csv
# Extracted 6 features in total EYE:GAZE_fixation_count
# ['EYE:GAZE_fixation_count', 'EYE:GAZE_fixation_total_duration', 'EYE:GAZE_fixation_mean_duration', 'EYE:GAZE_saccade_count', 'EYE:GAZE_saccade_total_duration', 'EYE:GAZE_saccade_mean_duration']
# (805, 10)
# stage
# 0    211
# 2    207
# 3    106
# 5    103
# 1    102
# 4     76
# Name: count, dtype: int64
# DONE!! trainning data/GAZE(6 4-2).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/GAZE_features_combined1-0.csv
# ===============
# empty columns []
# 5.550218340611353 Might have grouping error! ../data/MUWIS-dataset/features/GAZE_features_combined1-0.csv
# Extracted 6 features in total EYE:GAZE_fixation_count
# ['EYE:GAZE_fixation_count', 'EYE:GAZE_fixation_total_duration', 'EYE:GAZE_fixation_mean_duration', 'EYE:GAZE_saccade_count', 'EYE:GAZE_saccade_total_duration', 'EYE:GAZE_saccade_mean_duration']
# (834, 10)
# stage
# 0    211
# 2    209
# 5    107
# 3    106
# 1    103
# 4     98
# Name: count, dtype: int64
# DONE!! trainning data/GAZE(6 1-0).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/GAZE_features_combined2-1.csv
# ===============
# empty columns []
# 5.5152838427947595 Might have grouping error! ../data/MUWIS-dataset/features/GAZE_features_combined2-1.csv
# Extracted 6 features in total EYE:GAZE_fixation_count
# ['EYE:GAZE_fixation_count', 'EYE:GAZE_fixation_total_duration', 'EYE:GAZE_fixation_mean_duration', 'EYE:GAZE_saccade_count', 'EYE:GAZE_saccade_total_duration', 'EYE:GAZE_saccade_mean_duration']
# (830, 10)
# stage
# 0    211
# 2    208
# 5    107
# 3    106
# 1    102
# 4     96
# Name: count, dtype: int64
# DONE!! trainning data/GAZE(6 2-1).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/PUPIL_features_combined1-0.csv
# ===============
# empty columns []
# 5.5895196506550215 Might have grouping error! ../data/MUWIS-dataset/features/PUPIL_features_combined1-0.csv
# Extracted 26 features in total EYE:PUPIL_median
# ['EYE:PUPIL_median', 'EYE:PUPIL_max', 'EYE:PUPIL_min', 'EYE:PUPIL_mean', 'EYE:PUPIL_std', 'EYE:PUPIL_range', 'EYE:nblink', 'EYE:PUPIL_mean_RPD', 'EYE:PUPIL_max_RPD', 'EYE:PUPIL_min_RPD', 'EYE:PUPIL_std_RPD', 'EYE:PUPIL_range_RPD', 'EYE:PUPIL_pcl10_RPD', 'EYE:PUPIL_pcl25_RPD', 'EYE:PUPIL_pcl50_RPD', 'EYE:PUPIL_pcl75_RPD', 'EYE:PUPIL_pcl90_RPD', 'EYE:PUPIL_mean_RPDG', 'EYE:PUPIL_max_RPDG', 'EYE:PUPIL_min_RPDG', 'EYE:PUPIL_std_RPDG', 'EYE:PUPIL_range_RPDG', 'EYE:PUPIL_pcl25_RPDG', 'EYE:PUPIL_pcl50_RPDG', 'EYE:PUPIL_pcl75_RPDG', 'EYE:PUPIL_lhipa']
# (841, 30)
# stage
# 0    211
# 2    210
# 5    107
# 3    106
# 1    104
# 4    103
# Name: count, dtype: int64
# DONE!! trainning data/PUPIL(6 1-0).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/EDA_features_combined1-0.csv
# ===============
# empty columns []
# 5.686274509803922 Might have grouping error! ../data/MUWIS-dataset/features/EDA_features_combined1-0.csv
# Extracted 31 features in total E4:EDA_mean
# ['E4:EDA_mean', 'E4:EDA_median', 'E4:EDA_variance', 'E4:EDA_skewness', 'E4:EDA_kurtosis', 'E4:EDA_d1mean', 'E4:EDA_d2mean', 'E4:SCL_amp', 'E4:SCL_sd', 'E4:SCL_mean', 'E4:SCL_median', 'E4:SCL_max', 'E4:SCL_min', 'E4:SCR_range', 'E4:SCR_max', 'E4:SCR_min', 'E4:SCR_mean', 'E4:EDA_max', 'E4:EDA_min', 'E4:EDA_range', 'E4:SCL_range', 'E4:EDA_d1max', 'E4:EDA_d1min', 'E4:EDA_d1sd', 'E4:EDA_d1range', 'E4:EDA_d2max', 'E4:EDA_d2min', 'E4:EDA_d2sd', 'E4:EDA_d2range', 'E4:EDA_sd', 'E4:SCR_sd']
# (940, 35)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    116
# Name: count, dtype: int64
# DONE!! trainning data/EDA(6 1-0).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/PUPIL_features_combined4-2.csv
# ===============
# empty columns []
# 5.545851528384279 Might have grouping error! ../data/MUWIS-dataset/features/PUPIL_features_combined4-2.csv
# Extracted 26 features in total EYE:PUPIL_median
# ['EYE:PUPIL_median', 'EYE:PUPIL_max', 'EYE:PUPIL_min', 'EYE:PUPIL_mean', 'EYE:PUPIL_std', 'EYE:PUPIL_range', 'EYE:nblink', 'EYE:PUPIL_mean_RPD', 'EYE:PUPIL_max_RPD', 'EYE:PUPIL_min_RPD', 'EYE:PUPIL_std_RPD', 'EYE:PUPIL_range_RPD', 'EYE:PUPIL_pcl10_RPD', 'EYE:PUPIL_pcl25_RPD', 'EYE:PUPIL_pcl50_RPD', 'EYE:PUPIL_pcl75_RPD', 'EYE:PUPIL_pcl90_RPD', 'EYE:PUPIL_mean_RPDG', 'EYE:PUPIL_max_RPDG', 'EYE:PUPIL_min_RPDG', 'EYE:PUPIL_std_RPDG', 'EYE:PUPIL_range_RPDG', 'EYE:PUPIL_pcl25_RPDG', 'EYE:PUPIL_pcl50_RPDG', 'EYE:PUPIL_pcl75_RPDG', 'EYE:PUPIL_lhipa']
# (833, 30)
# stage
# 0    211
# 2    210
# 3    106
# 5    103
# 1    103
# 4    100
# Name: count, dtype: int64
# DONE!! trainning data/PUPIL(6 4-2).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/EDA_features_combined4-2.csv
# ===============
# empty columns []
# 5.674509803921569 Might have grouping error! ../data/MUWIS-dataset/features/EDA_features_combined4-2.csv
# Extracted 31 features in total E4:EDA_mean
# ['E4:EDA_mean', 'E4:EDA_median', 'E4:EDA_variance', 'E4:EDA_skewness', 'E4:EDA_kurtosis', 'E4:EDA_d1mean', 'E4:EDA_d2mean', 'E4:SCL_amp', 'E4:SCL_sd', 'E4:SCL_mean', 'E4:SCL_median', 'E4:SCL_max', 'E4:SCL_min', 'E4:SCR_range', 'E4:SCR_max', 'E4:SCR_min', 'E4:SCR_mean', 'E4:EDA_max', 'E4:EDA_min', 'E4:EDA_range', 'E4:SCL_range', 'E4:EDA_d1max', 'E4:EDA_d1min', 'E4:EDA_d1sd', 'E4:EDA_d1range', 'E4:EDA_d2max', 'E4:EDA_d2min', 'E4:EDA_d2sd', 'E4:EDA_d2range', 'E4:EDA_sd', 'E4:SCR_sd']
# (937, 35)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    113
# Name: count, dtype: int64
# DONE!! trainning data/EDA(6 4-2).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/EDA_features_combined2-1.csv
# ===============
# empty columns []
# 5.686274509803922 Might have grouping error! ../data/MUWIS-dataset/features/EDA_features_combined2-1.csv
# Extracted 31 features in total E4:EDA_mean
# ['E4:EDA_mean', 'E4:EDA_median', 'E4:EDA_variance', 'E4:EDA_skewness', 'E4:EDA_kurtosis', 'E4:EDA_d1mean', 'E4:EDA_d2mean', 'E4:SCL_amp', 'E4:SCL_sd', 'E4:SCL_mean', 'E4:SCL_median', 'E4:SCL_max', 'E4:SCL_min', 'E4:SCR_range', 'E4:SCR_max', 'E4:SCR_min', 'E4:SCR_mean', 'E4:EDA_max', 'E4:EDA_min', 'E4:EDA_range', 'E4:SCL_range', 'E4:EDA_d1max', 'E4:EDA_d1min', 'E4:EDA_d1sd', 'E4:EDA_d1range', 'E4:EDA_d2max', 'E4:EDA_d2min', 'E4:EDA_d2sd', 'E4:EDA_d2range', 'E4:EDA_sd', 'E4:SCR_sd']
# (940, 35)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    116
# Name: count, dtype: int64
# DONE!! trainning data/EDA(6 2-1).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/PUPIL_features_combined2-1.csv
# ===============
# empty columns []
# 5.580786026200873 Might have grouping error! ../data/MUWIS-dataset/features/PUPIL_features_combined2-1.csv
# Extracted 26 features in total EYE:PUPIL_median
# ['EYE:PUPIL_median', 'EYE:PUPIL_max', 'EYE:PUPIL_min', 'EYE:PUPIL_mean', 'EYE:PUPIL_std', 'EYE:PUPIL_range', 'EYE:nblink', 'EYE:PUPIL_mean_RPD', 'EYE:PUPIL_max_RPD', 'EYE:PUPIL_min_RPD', 'EYE:PUPIL_std_RPD', 'EYE:PUPIL_range_RPD', 'EYE:PUPIL_pcl10_RPD', 'EYE:PUPIL_pcl25_RPD', 'EYE:PUPIL_pcl50_RPD', 'EYE:PUPIL_pcl75_RPD', 'EYE:PUPIL_pcl90_RPD', 'EYE:PUPIL_mean_RPDG', 'EYE:PUPIL_max_RPDG', 'EYE:PUPIL_min_RPDG', 'EYE:PUPIL_std_RPDG', 'EYE:PUPIL_range_RPDG', 'EYE:PUPIL_pcl25_RPDG', 'EYE:PUPIL_pcl50_RPDG', 'EYE:PUPIL_pcl75_RPDG', 'EYE:PUPIL_lhipa']
# (840, 30)
# stage
# 0    211
# 2    210
# 5    107
# 3    106
# 4    103
# 1    103
# Name: count, dtype: int64
# DONE!! trainning data/PUPIL(6 2-1).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/ACC_features_combined2-1.csv
# ===============
# empty columns []
# 5.686274509803922 Might have grouping error! ../data/MUWIS-dataset/features/ACC_features_combined2-1.csv
# to combine with ../data/MUWIS-dataset/features/head motion_features_combined2-1.csv
# empty columns []
# 5.6875 Might have grouping error! ../data/MUWIS-dataset/features/head motion_features_combined2-1.csv
# before merge: (1450, 10) (1456, 13)
# after merge: (1450, 18)
# Extracted 13 features in total MOTION:WR_ACC_mean
# ['MOTION:WR_ACC_mean', 'MOTION:WR_ACC_sd', 'MOTION:WR_ACC_range', 'MOTION:WR_ACC_max', 'MOTION:WR_ACC_min', 'MOTION:HD_ACC_meanX', 'MOTION:HD_ACC_meanY', 'MOTION:HD_ACC_meanZ', 'MOTION:HD_MAG_meanX', 'MOTION:HD_MAG_meanY', 'MOTION:HD_MAG_meanZ', 'MOTION:HD_ACC_magmean', 'MOTION:HD_ACC_magenergy']
# (940, 17)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    116
# Name: count, dtype: int64
# DONE!! trainning data/MOTION(6 2-1).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/head motion_features_combined4-2.csv
# ===============
# empty columns []
# 5.6875 Might have grouping error! ../data/MUWIS-dataset/features/head motion_features_combined4-2.csv
# to combine with ../data/MUWIS-dataset/features/ACC_features_combined4-2.csv
# empty columns []
# 5.674509803921569 Might have grouping error! ../data/MUWIS-dataset/features/ACC_features_combined4-2.csv
# before merge: (1456, 13) (1447, 10)
# after merge: (1447, 18)
# Extracted 13 features in total MOTION:HD_ACC_meanX
# ['MOTION:HD_ACC_meanX', 'MOTION:HD_ACC_meanY', 'MOTION:HD_ACC_meanZ', 'MOTION:HD_MAG_meanX', 'MOTION:HD_MAG_meanY', 'MOTION:HD_MAG_meanZ', 'MOTION:HD_ACC_magmean', 'MOTION:HD_ACC_magenergy', 'MOTION:WR_ACC_mean', 'MOTION:WR_ACC_sd', 'MOTION:WR_ACC_range', 'MOTION:WR_ACC_max', 'MOTION:WR_ACC_min']
# (937, 17)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    113
# Name: count, dtype: int64
# DONE!! trainning data/MOTION(6 4-2).csv
# !!!!!!!!!!!!!!!
# ===============
# ../data/MUWIS-dataset/features/head motion_features_combined1-0.csv
# ===============
# empty columns []
# 5.6875 Might have grouping error! ../data/MUWIS-dataset/features/head motion_features_combined1-0.csv
# to combine with ../data/MUWIS-dataset/features/ACC_features_combined1-0.csv
# empty columns []
# 5.686274509803922 Might have grouping error! ../data/MUWIS-dataset/features/ACC_features_combined1-0.csv
# before merge: (1456, 13) (1450, 10)
# after merge: (1450, 18)
# Extracted 13 features in total MOTION:HD_ACC_meanX
# ['MOTION:HD_ACC_meanX', 'MOTION:HD_ACC_meanY', 'MOTION:HD_ACC_meanZ', 'MOTION:HD_MAG_meanX', 'MOTION:HD_MAG_meanY', 'MOTION:HD_MAG_meanZ', 'MOTION:HD_ACC_magmean', 'MOTION:HD_ACC_magenergy', 'MOTION:WR_ACC_mean', 'MOTION:WR_ACC_sd', 'MOTION:WR_ACC_range', 'MOTION:WR_ACC_max', 'MOTION:WR_ACC_min']
# (940, 17)
# stage
# 0    235
# 2    235
# 5    119
# 3    118
# 1    117
# 4    116
# Name: count, dtype: int64
# DONE!! trainning data/MOTION(6 1-0).csv
# !!!!!!!!!!!!!!!
